# %%
from f1_vault.data.data import split_episodes, analyze_dataset_statistics

# Test split_episodes
episodes = np.unique(episode_ids)
train, val, test = split_episodes(episodes)
print(f"Train: {len(train)}, Val: {len(val)}, Test: {len(test)}")

# Test analyze_dataset_statistics
stats = analyze_dataset_statistics('../data/raw/dynamics_data_0000.h5')
for key, value in stats.items():
    print(f"{key}: {value}")
